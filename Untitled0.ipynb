# %% [markdown]
# <a href="https://colab.research.google.com/github/bhatturvashi2618-sketch/capsproject1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import openai
import prog1
openai.api_key = prog1.OPENAI_API_KEY

text_to_translate = "Hello, how are you?"
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=f"Translate the following text to spanish,hindi and french:\n '{text_to_translate}'",
    #lower temperature makes response more focused amd deterministic, while higher temperature makes it more random and creative.
    temparature=0,
    max_tokens=60,
    #top_p is a parameter that controls the diversity of the generated text. A value of 0 means that the model will always choose the most likely next word, while a value of 1 means that the model will sample from the entire distribution of possible next words.
    top_p=0,
    #friquency_penalty is a parameter that controls how much the model penalizes repeated words in the generated text. A value of 0 means that the model will not penalize repeated words, while a value of 1 means that the model will heavily penalize repeated words.
    friquency_penalty=0,
    #presence_penalty is a parameter that controls how much the model penalizes words that are not present in the input text. A value of 0 means that the model will not penalize words that are not present in the input text, while a value of 1 means that the model will heavily penalize words that are not present in the input text.
    presence_penalty=0)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# /tmp/ipykernel_3280/2398599066.py in <cell line: 0>()
#       5
#       6 text_to_translate = "Hello, how are you?"
# ----> 7 response = openai.Completion.create(
#       8     engine="text-davinci-003",
#       9     prompt=f"Translate the following text to spanish,hindi and french:\n '{text_to_translate}'",
#
# /usr/local/lib/python3.12/dist-packages/openai/lib/_old_api.py in __call__(self, *_args, **_kwargs)
#      37
#      38     def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39         raise APIRemovedInV1(symbol=self._symbol)
#      40
#      41
#
# APIRemovedInV1:
#
# You tried to access openai.Completion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# ...
